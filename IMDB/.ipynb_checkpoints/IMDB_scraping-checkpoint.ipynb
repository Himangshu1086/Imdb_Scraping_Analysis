# %% [markdown]
# # WEB SCRAPING AND DATA ANALYSIS OF IMDB TOP 1000 MOVIES FROM 1921 TO 2021

# %%
pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# Requirement already satisfied: urllib3 in c:\users\himangshub\appdata\local\programs\python\python38-32\lib\site-packages (from selenium) (1.26.4)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
import time

# %%
PATH = "/usr/bin/chromedriver"

# %%
driver = webdriver.Chrome(PATH)
from selenium.webdriver.common.action_chains import ActionChains

# %% [markdown]
# ## Container for storing the attributes of the dataset

# %%
title_name = []
year = []
duration = []
genre = []
rating = []
overview = []
director = []
image_url = []
votes = []

# %% [markdown]
# ## Function to add title to list " title_name "

# %%
def add_title():
    title = driver.find_elements_by_class_name('lister-item-header')
    for i in title:
        title_name.append(i.find_element_by_tag_name('a').text)

# %% [markdown]
# ## Function to add year to list " year "

# %%
def add_year():
    yr = driver.find_elements_by_class_name('lister-item-year ')
    for i in yr:
        y = int(i.text.replace('(',"").replace(')',"").split()[-1])
        year.append(y)

# %% [markdown]
# ## Function to add duration to list " duration "

# %%
def add_duration():
    dur = driver.find_elements_by_class_name('runtime')
    for i in dur:
        duration.append(int(i.text.split()[0]))

# %% [markdown]
# ## Function to add genre to list " genre "

# %%
def add_genre():
    gen = driver.find_elements_by_class_name('genre')
    for i in gen:
        genre.append(i.text)

# %% [markdown]
# ## Function to add rating to list " rating "

# %%
def add_rating():
    rat = driver.find_elements_by_class_name('ratings-bar')
    for i in rat:
        rating.append(float(i.find_element_by_tag_name('strong').text))

# %% [markdown]
# ## Function to add overview to list " overview "

# %%
def add_overview():
    over = driver.find_elements_by_class_name("lister-item-content")
    for i in over:
        overview.append(i.find_elements_by_tag_name("p")[1].text)

# %% [markdown]
# ## Function to add director to list " director "

# %%
def add_director():
    dir = driver.find_elements_by_class_name("lister-item-content")
    for i in dir:
        director.append(i.find_elements_by_tag_name("p")[2].find_element_by_tag_name("a").text)

# %% [markdown]
# ## Function to add votes to list " votes "

# %%
def add_votes():
    vot = driver.find_elements_by_class_name("sort-num_votes-visible")
    for i in vot:
        votes.append(int(i.find_elements_by_name("nv")[0].text.replace(',',"")))

# %% [markdown]
# ## Function to add image url to list " image_url "

# %%
def add_image_url():
    img = driver.find_elements_by_class_name('lister-item-image')
    for i in img:
        image_url.append(i.find_element_by_tag_name("img").get_attribute("src"))

# %% [markdown]
# # Extracting all the data from the imdb website dynamically

# %%
for i in range(10):
    driver.get(f"https://www.imdb.com/search/title/?groups=top_1000&sort=user_rating,desc&count=100&start={i}01&ref_=adv_nxt")
    action = ActionChains(driver)
    add_title()
    add_year()
    add_duration()
    add_genre()
    add_rating()
    add_overview()
    add_director()
    add_image_url()
    add_votes()
    next = driver.find_element_by_link_text("Next »")
    action.click(next)
    action.perform()
    time.sleep(1)
driver.close()

# %%
len(votes)
# Out:
# 1000

# %% [markdown]
# # Creating a dataset using python dataframe

# %%
import pandas as pd

# %%
movie_dict = {
"movie-name":title_name,
"year":year,
"duration(min)":duration,
"genre":genre,
"rating":rating,
"overview":overview,
"director":director,
"image_url": image_url,
"votes":votes
}

# %%
Movie_df = pd.DataFrame(movie_dict)

# %%
Movie_df.head()
# Out:
#                  movie-name  year  duration(min)                 genre  \
# 0  The Shawshank Redemption  1994            142                 Drama
# 1             The Godfather  1972            175          Crime, Drama
# 2           Soorarai Pottru  2020            153                 Drama
# 3           The Dark Knight  2008            152  Action, Crime, Drama
# 4    The Godfather: Part II  1974            202          Crime, Drama
#
#    rating                                           overview  \
# 0     9.3  Two imprisoned men bond over a number of years...
# 1     9.2  An organized crime dynasty's aging patriarch t...
# 2     9.1  Nedumaaran Rajangam "Maara" sets out to make t...
# 3     9.0  When the menace known as the Joker wreaks havo...
# 4     9.0  The early life and career of Vito Corleone in ...
#
#                director                                          image_url  \
# 0        Frank Darabont  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  Francis Ford Coppola  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2         Sudha Kongara  https://m.media-amazon.com/images/M/MV5BOGVjYm...
# 3     Christopher Nolan  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 4  Francis Ford Coppola  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#      votes
# 0  2429850
# 1  1682074
# 2    85875
# 3  2385740
# 4  1167567

# %% [markdown]
# ##  Creating a CSV File

# %%
Movie_df.to_csv("IMDB-Movies-top-1k.csv" , index=None)

# %% [markdown]
# # DATA ANALYSIS

# %% [markdown]
# # BASIC INSTALLATION OF LIBRARIES

# %%
import pandas as pd
from IPython.core.display import HTML
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # READING THE DATASET (CSV) USING PANDAS

# %%
df_imdb =pd.read_csv('IMDB-Movies-top-1k.csv')

# %% [markdown]
# # INTRODUCTORY ANALYSIS OF DATASET

# %%
df_imdb.sort_values('year').head()
# Out:
#                       movie-name  year  duration(min)  \
# 335  The Cabinet of Dr. Caligari  1920             67
# 133                      The Kid  1921             68
# 581                    Nosferatu  1922             94
# 198                 Sherlock Jr.  1924             45
# 197                The Gold Rush  1925             95
#
#                         genre  rating  \
# 335  Fantasy, Horror, Mystery     8.1
# 133     Comedy, Drama, Family     8.3
# 581           Fantasy, Horror     7.9
# 198   Action, Comedy, Romance     8.2
# 197  Adventure, Comedy, Drama     8.2
#
#                                               overview         director  \
# 335  Hypnotist Dr. Caligari uses a somnambulist, Ce...     Robert Wiene
# 133  The Tramp cares for an abandoned child, but ev...  Charles Chaplin
# 581  Vampire Count Orlok expresses interest in a ne...      F.W. Murnau
# 198  A film projectionist longs to be a detective, ...    Buster Keaton
# 197  A prospector goes to the Klondike in search of...  Charles Chaplin
#
#                                              image_url   votes
# 335  https://m.media-amazon.com/images/S/sash/4Fyxw...   59336
# 133  https://m.media-amazon.com/images/S/sash/4Fyxw...  117964
# 581  https://m.media-amazon.com/images/S/sash/4Fyxw...   91106
# 198  https://m.media-amazon.com/images/S/sash/4Fyxw...   44584
# 197  https://m.media-amazon.com/images/S/sash/4Fyxw...  104631

# %%
df_imdb.sort_values('year').tail()
# Out:
#                         movie-name  year  duration(min)  \
# 209                           Soul  2020            100
# 95       Demon Slayer: Mugen Train  2020            117
# 229   Zack Snyder's Justice League  2021            242
# 21                      Drishyam 2  2021            152
# 728  The Mitchells vs the Machines  2021            113
#
#                             genre  rating  \
# 209  Animation, Adventure, Comedy     8.1
# 95   Animation, Action, Adventure     8.3
# 229    Action, Adventure, Fantasy     8.1
# 21         Crime, Drama, Thriller     8.6
# 728  Animation, Adventure, Comedy     7.7
#
#                                               overview        director  \
# 209  After landing the gig of a lifetime, a New Yor...     Pete Docter
# 95   After his family was brutally murdered and his...  Haruo Sotozaki
# 229  Determined to ensure Superman's ultimate sacri...     Zack Snyder
# 21   A gripping tale of an investigation and a fami...   Jeethu Joseph
# 728  A quirky, dysfunctional family's road trip is ...  Michael Rianda
#
#                                              image_url   votes
# 209  https://m.media-amazon.com/images/S/sash/4Fyxw...  266085
# 95   https://m.media-amazon.com/images/S/sash/4Fyxw...   30294
# 229  https://m.media-amazon.com/images/S/sash/4Fyxw...  318072
# 21   https://m.media-amazon.com/images/S/sash/4Fyxw...   29181
# 728  https://m.media-amazon.com/images/S/sash/4Fyxw...   69005

# %%
def path_to_image_html(path):
    return '<img src="'+ path + '" width="120" >'
df_imdb.to_html(escape=False, formatters=dict(image_url=path_to_image_html))
HTML(df_imdb.to_html(escape=False,formatters=dict(image_url=path_to_image_html)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>movie-name</th>
#       <th>year</th>
#       <th>duration(min)</th>
#       <th>genre</th>
#       <th>rating</th>
#       <th>overview</th>
#       <th>director</th>
#       <th>image_url</th>
#       <th>votes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>The Shawshank Redemption</td>
#       <td>1994</td>
#       <td>142</td>
#       <td>Drama</td>
#       <td>9.3</td>
#       <td>Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.</td>
#       <td>Frank Darabont</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg" width="120" ></td>
#       <td>2429850</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>The Godfather</td>
#       <td>1972</td>
#       <td>175</td>
#       <td>Crime, Drama</td>
#       <td>9.2</td>
#       <td>An organized crime dynasty's aging patriarch transfers control of his clandestine empire to his reluctant son.</td>
#       <td>Francis Ford Coppola</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY98_CR1,0,67,98_AL_.jpg" width="120" ></td>
#       <td>1682074</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Soorarai Pottru</td>
#       <td>2020</td>
#       <td>153</td>
#       <td>Drama</td>
#       <td>9.1</td>
#       <td>Nedumaaran Rajangam "Maara" sets out to make the common man fly and in the process takes on the world's most capital intensive industry and several enemies who stand in his way.</td>
#       <td>Sudha Kongara</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BOGVjYmM0ZWEtNTFjNi00MWZjLTk3OTItMmFjMDAzZWU1ZDVjXkEyXkFqcGdeQXVyMTI2Mzk1ODg0._V1_UX67_CR0,0,67,98_AL_.jpg" width="120" ></td>
#       <td>85875</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>The Dark Knight</td>
#       <td>2008</td>
#       <td>152</td>
#       <td>Action, Crime, Drama</td>
#       <td>9.0</td>
#       <td>When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.</td>
#       <td>Christopher Nolan</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX67_CR0,0,67,98_AL_.jpg" width="120" ></td>
#       <td>2385740</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>The Godfather: Part II</td>
#       <td>1974</td>
#       <td>202</td>
#       <td>Crime, Drama</td>
#       <td>9.0</td>
#       <td>The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.</td>
#       <td>Francis Ford Coppola</td>
#       <td><img src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="120" ></td>
#       <td>1167567</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>12 Angry Men</td>
#       <td>1957</td>
#       <td>96</td>
#       <td>Crime, Drama</td>
#       <td>9.0</td>
#       <td>A jury holdout attempts to prevent a miscarriage of justice by forcing his colleagues to reconsider the evidence.</td>
#       <td>Sidney Lumet</td>
#       <td><img src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="120" ></td>
#       <td>717295</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Dara of Jasenovac</td>
#       <td>2020</td>
#       <td>130</td>
#       <td>Drama, War</td>
#       <td>8.9</td>
#       <td>Follows the story of a young girl named Dara who is sent to a concentration camp in Croatia during World War 2.</td>
#       <td>Predrag Antonijevic</td>
#       <td><img src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="120" ></td>
#       <td>36937</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>The Lord of the Rings: The Return of the King</td>
#       <td>2003</td>
#       <td>201</td>
#       <td>Action, Adventure, Drama</td>
#       <td>8.9</td>
#       <td>Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.</td>
#       <td>Peter Jackson</td>
#       <td><img src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="120" ></td>
#       <td>1690502</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Pulp Fiction</td>
#       <td>1994</td>
#       <td>154</td>
#       <td>Crime, Drama</td>
#       <td>8.9</td>
#       <td>The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption.</td>
#       <td>Quentin Tarantino</td>
#       <td><img src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="120" ></td>
#       <td>1885285</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Schindler's List</td>
#       <td>1993</td>
#       <td>195</td>
#       <td>Biography, Drama, History</td>
#       <td>8.9</td>
#       <td>In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.</td>
#       <td>Steven Spielberg</td>
#       <td><img src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="120" ></td>
#       <td>1250735</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Inception</td>
#       <td>2010</td>
#       <td>148</td>
#       <td>Action, Adventure, Sci-Fi</td>
#       <td>8.8</td>
#       <td>A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O.</td>
#       <td>Christopher Nolan</td>
#       <td><img src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="120" ></td>
#       <td>2141317</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Fight Club</td>
#       <td>1999</td>
#       <td>139</td>
#       <td>Drama</td>
#       <td>8.8</td>
#       <td>An insomniac office worker and a devil-may-care soap maker form an underground fight club that evolves into much more.</td>
#       <td>David Fincher</td>
#       <td><img src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="120" ></td>
#       <td>1916428</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>The Lord of the Rings: The Fellowship of the Ring</td>
#       <td>2001</td>
#       <td>178</td>
#       <td>Action, Adventure, Drama</td>
#       <td>8.8</td>
#       <td>A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.</td>
#       <td>Peter Jackson</td>
#       <td><img src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="120" ></td>
#       <td>1711745</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Forrest Gump</td>
#       <td>1994</td>
#       <td>142</td>
#       <td>Drama, Romance</td>
#       <td>8.8</td>
#       <td>The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.</td>
#       <td>Robert Zemeckis</td>
#       <td><img src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="120" ></td>
#       <td>1878044</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>The Good, the Bad and the Ugly</td>
#       <td>1966</td>
#       <td>178</td>
#       <td>Western</td>
#       <td>8.8</td>
#       <td>A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.</td>
#       <td>Sergio Leone</td>
#       <td><img src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="120" ></td>
#       <td>708867</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>The Lord of the Rings: The Two Towers</td>
#       <td>2002</td>
#       <td>179</td>
#       <td>Ac

# %%
df_imdb.columns
# Out:
# Index(['movie-name', 'year', 'duration(min)', 'genre', 'rating', 'overview',
#        'director', 'image_url', 'votes'],
#       dtype='object')

# %%
df_imdb.shape
# Out:
# (1000, 9)

# %%
df_imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie-name     1000 non-null   object
#  1   year           1000 non-null   int64
#  2   duration(min)  1000 non-null   int64
#  3   genre          1000 non-null   object
#  4   rating         1000 non-null   float64
#  5   overview       1000 non-null   object
#  6   director       1000 non-null   object
#  7   image_url      1000 non-null   object
#  8   votes          1000 non-null   int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 70.4+ KB

# %%
df_imdb.describe()
# Out:
#               year  duration(min)       rating         votes
# count  1000.000000    1000.000000  1000.000000  1.000000e+03
# mean   1991.238000     122.998000     7.953900  2.792805e+05
# std      23.403014      28.221028     0.275936  3.345355e+05
# min    1920.000000      45.000000     7.600000  2.522100e+04
# 25%    1976.000000     103.000000     7.700000  5.580225e+04
# 50%    1999.000000     119.000000     7.900000  1.416020e+05
# 75%    2010.000000     137.000000     8.100000  3.813432e+05
# max    2021.000000     321.000000     9.300000  2.396103e+06

# %% [markdown]
# # Insights

# %% [markdown]
# - Dataset contains movies from year 1920 to 2021
# - The dataset contain 1000 movie with 9 columns of details.
# - The maximum duration of movie is 321 minutes and minimum duration is 45 minutes.
# - Maximum rating is 9.3 and minimum rating is 7.6

# %% [markdown]
# # CHECK FOR MISSING DATA

# %%
df_imdb.isnull()
# Out:
#      movie-name   year  duration(min)  genre  rating  overview  director  \
# 0         False  False          False  False   False     False     False
# 1         False  False          False  False   False     False     False
# 2         False  False          False  False   False     False     False
# 3         False  False          False  False   False     False     False
# 4         False  False          False  False   False     False     False
# ..          ...    ...            ...    ...     ...       ...       ...
# 995       False  False          False  False   False     False     False
# 996       False  False          False  False   False     False     False
# 997       False  False          False  False   False     False     False
# 998       False  False          False  False   False     False     False
# 999       False  False          False  False   False     False     False
#
#      image_url  votes
# 0        False  False
# 1        False  False
# 2        False  False
# 3        False  False
# 4        False  False
# ..         ...    ...
# 995      False  False
# 996      False  False
# 997      False  False
# 998      False  False
# 999      False  False
#
# [1000 rows x 9 columns]

# %%
df_imdb[df_imdb.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [movie-name, year, duration(min), genre, rating, overview, director, image_url, votes]
# Index: []

# %% [markdown]
# ### There is no missing data in the dataset

# %% [markdown]
# # YEAR ANALYSIS

# %%
year_of_release = df_imdb['year']
year_of_release
# Out:
# 0      1994
# 1      1972
# 2      2020
# 3      2008
# 4      1974
#        ...
# 995    1961
# 996    1956
# 997    1953
# 998    1953
# 999    1944
# Name: year, Length: 1000, dtype: int64

# %% [markdown]
# ### graph of year and number of movies

# %%
no_movie_years = df_imdb.year.value_counts().sort_index(ascending=False)
no_movie_years
# Out:
# 2021     3
# 2020     8
# 2019    24
# 2018    20
# 2017    23
#         ..
# 1925     2
# 1924     1
# 1922     1
# 1921     1
# 1920     1
# Name: year, Length: 100, dtype: int64

# %%
from matplotlib import rcParams

# %% [markdown]
# Changing the Defaults: rcParams
#
# Each time Matplotlib loads, it defines a runtime configuration (rc) containing the default styles for every plot element you create. This configuration can be adjusted at any time using the plt.

# %%
    rcParams['figure.figsize'] = (80,7)
    sns.barplot(x=df_imdb.year.value_counts().index , y=df_imdb.year.value_counts())
    plt.title("year vs number of movies")
    plt.xlabel("year")
    plt.ylabel("no of movies")
# Out:
# Text(0, 0.5, 'no of movies')

# %% [markdown]
# ## function for graph number of movie vs year

# %%
def graph_for_movies_number_in_each_year(i,j):
    x_axis = df_imdb.year.value_counts().sort_index().index[i:j]
    y_axis = df_imdb.year.value_counts().sort_index()[i:j]
    sns.barplot(x=x_axis , y=y_axis);
    plt.title("year vs number of movies")
    plt.xlabel("year")
    plt.ylabel("no of movies")
    sns.set_theme(style="whitegrid")

# %% [markdown]
# ## First 10 Year Graph

# %%
rcParams['figure.figsize'] = (10,7)
graph_for_movies_number_in_each_year(0,9)

# %% [markdown]
# ## LAST 10 YEARS DATA

# %%
graph_for_movies_number_in_each_year(89,101)

# %%
df_imdb.year.value_counts().sort_index(ascending=False)[:11].plot.pie(autopct='%1.1f%%' , figsize=(10,10))
plt.title('LAST TEN YEAR MOVIES WITH %')
# Out:
# Text(0.5, 1.0, 'LAST TEN YEAR MOVIES WITH %')

# %% [markdown]
# # top 10 years with the most number of movie released

# %%
df_imdb.year.value_counts().head(10)
# Out:
# 2004    33
# 2014    31
# 2009    29
# 2016    28
# 2013    28
# 2006    26
# 2007    26
# 2001    26
# 2015    24
# 2012    24
# Name: year, dtype: int64

# %%
df_imdb.year.value_counts().head(10).plot.bar(color="g")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## MOVIES LIST OF THE YEAR HAVING THE MOST NUMBER OF MOVIES i.e 2004

# %%
df_imdb.year.value_counts()[:1]
# Out:
# 2004    33
# Name: year, dtype: int64

# %%
df_imdb[df_imdb['year']==2004]
# Out:
#                                    movie-name  year  duration(min)  \
# 95      Eternal Sunshine of the Spotless Mind  2004            108
# 157                                    Swades  2004            189
# 158                                  Downfall  2004            156
# 159                      Howl's Moving Castle  2004            119
# 235                              Nobody Knows  2004            141
# 237                       Million Dollar Baby  2004            132
# 238                              Hotel Rwanda  2004            121
# 239                             Before Sunset  2004             80
# 373                                    3-Iron  2004             88
# 376        Tae Guk Gi: The Brotherhood of War  2004            140
# 377                                  G.O.R.A.  2004            127
# 380                         Kill Bill: Vol. 2  2004            137
# 383                            The Sea Inside  2004            126
# 388                           The Incredibles  2004            115
# 508                                The Chorus  2004             97
# 510                         Shaun of the Dead  2004             99
# 512                                   Head-On  2004            121
# 514  Harry Potter and the Prisoner of Azkaban  2004            142
# 638                                Veer-Zaara  2004            192
# 646                              The Notebook  2004            123
# 647                    The Motorcycle Diaries  2004            126
# 780                                     Crash  2004            112
# 781                            Kung Fu Hustle  2004             99
# 782                      The Bourne Supremacy  2004            108
# 783                             The Machinist  2004            101
# 784                                       Ray  2004            152
# 787                               Man on Fire  2004            146
# 791                         Finding Neverland  2004            106
# 935                          Dead Man's Shoes  2004             90
# 941                                       Saw  2004            103
# 942                           Mysterious Skin  2004            105
# 943                    A Very Long Engagement  2004            133
# 948                      The Butterfly Effect  2004            113
#
#                             genre  rating  \
# 95         Drama, Romance, Sci-Fi     8.3
# 157                         Drama     8.2
# 158     Biography, Drama, History     8.2
# 159  Animation, Adventure, Family     8.2
# 235                         Drama     8.1
# 237                  Drama, Sport     8.1
# 238     Biography, Drama, History     8.1
# 239                Drama, Romance     8.1
# 373         Crime, Drama, Romance     8.0
# 376            Action, Drama, War     8.0
# 377     Adventure, Comedy, Sci-Fi     8.0
# 380       Action, Crime, Thriller     8.0
# 383              Biography, Drama     8.0
# 388  Animation, Action, Adventure     8.0
# 508          Comedy, Drama, Music     7.9
# 510                Comedy, Horror     7.9
# 512                Drama, Romance     7.9
# 514    Adventure, Family, Fantasy     7.9
# 638        Drama, Family, Musical     7.8
# 646                Drama, Romance     7.8
# 647   Adventure, Biography, Drama     7.8
# 780        Crime, Drama, Thriller     7.7
# 781       Action, Comedy, Fantasy     7.7
# 782     Action, Mystery, Thriller     7.7
# 783               Drama, Thriller     7.7
# 784       Biography, Drama, Music     7.7
# 787          Action, Crime, Drama     7.7
# 791      Biography, Drama, Family     7.7
# 935        Crime, Drama, Thriller     7.6
# 941     Horror, Mystery, Thriller     7.6
# 942                         Drama     7.6
# 943       Drama, Mystery, Romance     7.6
# 948       Drama, Sci-Fi, Thriller     7.6
#
#                                               overview              director  \
# 95   When their relationship turns sour, a couple u...         Michel Gondry
# 157  A successful Indian scientist returns to an In...    Ashutosh Gowariker
# 158  Traudl Junge, the final secretary for Adolf Hi...   Oliver Hirschbiegel
# 159  When an unconfident young woman is cursed with...        Hayao Miyazaki
# 235  In a small Tokyo apartment, twelve-year-old Ak...      Hirokazu Koreeda
# 237  A determined woman works with a hardened boxin...        Clint Eastwood
# 238  Paul Rusesabagina, a hotel manager, houses ove...          Terry George
# 239  Nine years after Jesse and Celine first met, t...     Richard Linklater
# 373  A transient young man breaks into empty homes ...            Kim Ki-duk
# 376  When two brothers are forced to fight in the K...           Je-kyu Kang
# 377  A slick young Turk kidnapped by extraterrestri...      Ömer Faruk Sorak
# 380  The Bride continues her quest of vengeance aga...     Quentin Tarantino
# 383  The factual story of Spaniard Ramon Sampedro, ...    Alejandro Amenábar
# 388  A family of undercover superheroes, while tryi...             Brad Bird
# 508  The new teacher at a severely administered boy...  Christophe Barratier
# 510  A man's uneventful life is disrupted by the zo...          Edgar Wright
# 512  With the intention to break free from the stri...            Fatih Akin
# 514  Harry Potter, Ron and Hermione return to Hogwa...        Alfonso Cuarón
# 638  Veer-Zaara is a saga of love, separation, cour...           Yash Chopra
# 646  A poor yet passionate young man falls in love ...       Nick Cassavetes
# 647  The dramatization of a motorcycle road trip Ch...         Walter Salles
# 780  Los Angeles citizens with vastly separate live...           Paul Haggis
# 781  In Shanghai, China in the 1940s, a wannabe gan...          Stephen Chow
# 782  When Jason Bourne is framed for a CIA operatio...       Paul Greengrass
# 783  An industrial worker who hasn't slept in a yea...         Brad Anderson
# 784  The story of the life and career of the legend...       Taylor Hackford
# 787  In Mexico City, a former CIA operative swears ...            Tony Scott
# 791  The story of Sir J.M. Barrie's friendship with...          Marc Forster
# 935  A disaffected soldier returns to his hometown ...         Shane Meadows
# 941  Two strangers awaken in a room with no recolle...             James Wan
# 942  A teenage hustler and a young man obsessed wit...           Gregg Araki
# 943  Tells the story of a young woman's relentless ...    Jean-Pierre Jeunet
# 948  Evan Treborn suffers blackouts during signific...            Eric Bress
#
#                                              image_url   votes
# 95   https://m.media-amazon.com/images/S/sash/4Fyxw...  927801
# 157  https://m.media-amazon.com/images/S/sash/4Fyxw...   84879
# 158  https://m.media-amazon.com/images/S/sash/4Fyxw...  336225
# 159  https://m.media-amazon.com/images/S/sash/4Fyxw...  345231
# 235  https://m.media-amazon.com/images/S/sash/4Fyxw...   25517
# 237  https://m.media-amazon.com/images/S/sash/4Fyxw...  645945
# 238  https://m.media-amazon.com/images/S/sash/4Fyxw...  338613
# 239  https://m.media-amazon.com/images/S/sash/4Fyxw...  241757
# 373  https://m.media-amazon.com/images/S/sash/4Fyxw...   51761
# 376  https://m.media-amazon.com/images/S/sash/4Fyxw...   38160
# 377  https://m.media-amazon.com/images/S/sash/4Fyxw...   58424
# 380  https://m.media-amazon.com/images/S/sash/4Fyxw...  695505
# 383  https://m.media-amazon.com/images/S/sash/4Fyxw...   78512
# 388  https://m.media-amazon.com/images/S/sash/4Fyxw...  667519
# 508  https://m.media-amazon.com/images/S/sash/4Fyxw...   58477
# 510  https://m.media-amazon.com/images/S/sash/4Fyxw...  520318
# 512  https://m.media-amazon.com/images/S/sash/4Fyxw...   51993
# 514  https://m.media-amazon.com/images/S/sash/4Fyxw...  564604
# 638  https://m.media-amazon.com/images/S/sash/4Fyxw...   49878
# 646  https://m.media-amazon.com/images/S/sash/4Fyxw...  530253
# 647  https://m.media-amazon.com/images/S/sash/4Fyxw...   97864
# 780  https://m.media-amazon.com/images/S/sash/4Fyxw...  423180
# 781  https://m.media-amazon.com/images/S/sash/4Fyxw...  129469
# 782  https://m.media-amazon.com/images/S/sash/4Fyxw...  440093
# 783  https://m.media-amazon.com/images/S/sash/4Fyxw...  363882
# 784  https://m.media-amazon.com/images/S/sash/4Fyxw...  140401
# 787  https://m.media-amazon.com/images/S/sash/4Fyxw...  334206
# 791  https://m.media-amazon.com/images/S/sash/4Fyxw...  200360
# 935  https://m.media-amazon.com/images/S/sash/4Fyxw...   50412
# 941  https://m.media-amazon.com/images/S/sash/4Fyxw...  385939
# 942  https://m.media-amazon.com/images/S/sash/4Fyxw...   66546
# 943  https://m.media-amazon.com/images/S/sash/4Fyxw...   71431
# 948  https://m.media-amazon.com/images/S/sash/4Fyxw...  457092

# %% [markdown]
# ## Movies with  maximum and minimum rating in 2004

# %%
max_rating = df_imdb[df_imdb['year']==2004].rating.max()
max_rating
# Out:
# 8.3

# %%
df_imdb[df_imdb['year']==2004][df_imdb.rating == max_rating]
# Out:
# /home/himangshu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                movie-name  year  duration(min)  \
# 99  Eternal Sunshine of the Spotless Mind  2004            108
#
#                      genre  rating  \
# 99  Drama, Romance, Sci-Fi     8.3
#
#                                              overview       director  \
# 99  When their relationship turns sour, a couple u...  Michel Gondry
#
#                                             image_url   votes
# 99  https://m.media-amazon.com/images/S/sash/4Fyxw...  938481

# %%
min_rating = df_imdb[df_imdb['year']==2004].rating.min()
min_rating
# Out:
# 7.6

# %%
df_imdb[df_imdb['year']==2004][df_imdb.rating == min_rating]['movie-name'].to_numpy()
# Out:
# /home/himangshu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# array(["Dead Man's Shoes", 'Saw', 'Mysterious Skin',
#        'A Very Long Engagement', 'The Butterfly Effect'], dtype=object)

# %% [markdown]
# ### Movies with maximum votes

# %%
max_votes = df_imdb[df_imdb['year']==2004].votes.max()
max_votes
# Out:
# 938481

# %%
df_imdb[df_imdb['year']==2004][df_imdb.votes == max_votes]
# Out:
# /home/himangshu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                movie-name  year  duration(min)  \
# 99  Eternal Sunshine of the Spotless Mind  2004            108
#
#                      genre  rating  \
# 99  Drama, Romance, Sci-Fi     8.3
#
#                                              overview       director  \
# 99  When their relationship turns sour, a couple u...  Michel Gondry
#
#                                             image_url   votes
# 99  https://m.media-amazon.com/images/S/sash/4Fyxw...  938481

# %% [markdown]
# ## Genre check

# %%
df_imdb[df_imdb['year']==2004].genre.value_counts().sort_values(ascending =False)
# Out:
# Drama, Romance                  3
# Drama                           3
# Biography, Drama, History       2
# Crime, Drama, Thriller          2
# Drama, Thriller                 1
# Drama, Family, Musical          1
# Action, Drama, War              1
# Animation, Action, Adventure    1
# Adventure, Comedy, Sci-Fi       1
# Drama, Sci-Fi, Thriller         1
# Crime, Drama, Romance           1
# Drama, Sport                    1
# Biography, Drama                1
# Animation, Adventure, Family    1
# Horror, Mystery, Thriller       1
# Action, Comedy, Fantasy         1
# Action, Crime, Thriller         1
# Drama, Mystery, Romance         1
# Biography, Drama, Family        1
# Adventure, Biography, Drama     1
# Action, Crime, Drama            1
# Biography, Drama, Music         1
# Comedy, Drama, Music            1
# Comedy, Horror                  1
# Adventure, Family, Fantasy      1
# Action, Mystery, Thriller       1
# Drama, Romance, Sci-Fi          1
# Name: genre, dtype: int64

# %% [markdown]
# # Movies in 2004 with graph

# %%
year_with_most_movie_list_movie_name = df_imdb[(df_imdb['year']==2004)]['movie-name']
year_with_most_movie_list_duration = df_imdb[(df_imdb['year']==2004)]['duration(min)']
year_with_most_movie_list = {
    "movie_name of 2004" : year_with_most_movie_list_movie_name,
    "duration" : year_with_most_movie_list_duration
}
year_with_most_movie_list_and_duration = pd.DataFrame(year_with_most_movie_list)
year_with_most_movie_list_and_duration
# Out:
#                            movie_name of 2004  duration
# 99      Eternal Sunshine of the Spotless Mind       108
# 162                                    Swades       189
# 163                                  Downfall       156
# 164                      Howl's Moving Castle       119
# 239                              Nobody Knows       141
# 241                       Million Dollar Baby       132
# 242                              Hotel Rwanda       121
# 243                             Before Sunset        80
# 377                                    3-Iron        88
# 380        Tae Guk Gi: The Brotherhood of War       140
# 381                                  G.O.R.A.       127
# 384                         Kill Bill: Vol. 2       137
# 387                            The Sea Inside       126
# 392                           The Incredibles       115
# 511                                The Chorus        97
# 513                         Shaun of the Dead        99
# 515                                   Head-On       121
# 517  Harry Potter and the Prisoner of Azkaban       142
# 643                                Veer-Zaara       192
# 651                              The Notebook       123
# 652                    The Motorcycle Diaries       126
# 787                                     Crash       112
# 788                            Kung Fu Hustle        99
# 789                      The Bourne Supremacy       108
# 790                             The Machinist       101
# 791                                       Ray       152
# 794                               Man on Fire       146
# 798                         Finding Neverland       106
# 938                          Dead Man's Shoes        90
# 943                                       Saw       103
# 944                           Mysterious Skin       105
# 945                    A Very Long Engagement       133
# 950                      The Butterfly Effect       113

# %%
sns.barplot( y="movie_name of 2004" , x="duration" ,data = year_with_most_movie_list_and_duration )
plt.title("MOVIES RELEASED IN 2004")
plt.xlabel("duration in min")
# Out:
# Text(0.5, 0, 'duration in min')

# %% [markdown]
# # Information after analysising Year column

# %% [markdown]
# - 3.1 percent of the movies released in 2014.
# - 31 movies has been released in 2014.
# - 2004 is the year with the most number of movies released-33 movies , followed by year 2014 with 31 movies and 29 movies in the year 2009.
# - Most of the movies released in 2004 have genre DRAMA
# - The most rated movie in 2004 is "Eternal Sunshine of the Spotless Mind" with 8.3 rating and 938481 votes
# - The minimum rating is 7.6 which is the lowest rating from 1920 to 2021
# - Five movies got the lowest rating in 2004 , the movies are :
#      - Dead Man's Shoes
#      - Saw
#      - Mysterious Skin
#      - A Very Long Engagement
#      - The Butterfly Effect

# %% [markdown]
# # DURATION ANALYSIS

# %%
df_imdb.head()
# Out:
#                  movie-name  year  duration(min)                 genre  \
# 0  The Shawshank Redemption  1994            142                 Drama
# 1             The Godfather  1972            175          Crime, Drama
# 2           Soorarai Pottru  2020            153                 Drama
# 3           The Dark Knight  2008            152  Action, Crime, Drama
# 4    The Godfather: Part II  1974            202          Crime, Drama
#
#    rating                                           overview  \
# 0     9.3  Two imprisoned men bond over a number of years...
# 1     9.2  An organized crime dynasty's aging patriarch t...
# 2     9.1  Nedumaaran Rajangam "Maara" sets out to make t...
# 3     9.0  When the menace known as the Joker wreaks havo...
# 4     9.0  The early life and career of Vito Corleone in ...
#
#                director                                          image_url  \
# 0        Frank Darabont  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  Francis Ford Coppola  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2         Sudha Kongara  https://m.media-amazon.com/images/M/MV5BOTc2ZT...
# 3     Christopher Nolan  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 4  Francis Ford Coppola  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#      votes
# 0  2396103
# 1  1659703
# 2    79558
# 3  2357666
# 4  1153712

# %% [markdown]
# ## DURATION VS NUMBER OF MOVIES

# %%
duration_vs_no_of_movies = df_imdb['duration(min)'].value_counts().to_frame().rename_axis("duration in min").reset_index().rename(columns={"duration(min)":"no of movies"})

duration_vs_no_of_movies
# Out:
#      duration in min  no of movies
# 0                130            24
# 1                100            22
# 2                129            22
# 3                113            22
# 4                101            21
# ..               ...           ...
# 134              174             1
# 135              175             1
# 136              177             1
# 137              184             1
# 138              321             1
#
# [139 rows x 2 columns]

# %%
duration_vs_no_of_movies.sort_values("no of movies" , ascending=False).head(10)
# Out:
#     duration in min  no of movies
# 0               130            24
# 2               129            22
# 3               113            22
# 1               100            22
# 4               101            21
# 5               102            20
# 6               122            20
# 7               110            19
# 9               118            18
# 10              120            18

# %% [markdown]
# ## top 10 duration with the maximum number of movies

# %%
fig, ax = plt.subplots(figsize=(10,7))
sns.barplot(x='duration in min' , y='no of movies' ,data=duration_vs_no_of_movies.sort_values("no of movies",ascending=False).head(10))
plt.title("top 10 duration with the maximum number of movies")
# Out:
# Text(0.5, 1.0, 'top 10 duration with the maximum number of movies')

# %%
df_imdb["duration(min)"].value_counts().head(10).plot.pie(autopct='%1.1f%%' , figsize=(10,10))
plt.legend()
plt.title("PIE CHART -- Duration(min) vs no of movies ")
# Out:
# Text(0.5, 1.0, 'PIE CHART -- Duration(min) vs no of movies ')

# %% [markdown]
# ## histogram of duration in min

# %%
sns.distplot(df_imdb['duration(min)'], hist=True, kde=False, color ='green', bins=20, rug=True,
             hist_kws={'edgecolor':'black'})
plt.ylabel("frequency of movies")
# Out:
# C:\Users\HIMANGSHUB\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HIMANGSHUB\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'frequency of movies')

# %%
sns.distplot(df_imdb['duration(min)'], hist=False, rug=True);
# Out:
# C:\Users\HIMANGSHUB\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HIMANGSHUB\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## TOP TEN MOVIES WITH DURATION

# %%
top_ten_movie_with_highest_time = df_imdb.sort_values("duration(min)" , ascending=False).head(10)
sns.barplot(y="movie-name" , x="duration(min)" , data=top_ten_movie_with_highest_time )
# Out:
# <AxesSubplot:xlabel='duration(min)', ylabel='movie-name'>

# %% [markdown]
# ## TEN MOVIES WITH LEAST DURATION

# %%
ten_movie_with_LOWEST_time = df_imdb.sort_values("duration(min)" , ascending=True).head(10)
sns.barplot(y="movie-name" , x="duration(min)" , data=ten_movie_with_LOWEST_time )
# Out:
# <AxesSubplot:xlabel='duration(min)', ylabel='movie-name'>

# %%
# Out:
# 0      The Shawshank Redemption
# 1                 The Godfather
# 2               Soorarai Pottru
# 3               The Dark Knight
# 4        The Godfather: Part II
#                  ...
# 995      Breakfast at Tiffany's
# 996                       Giant
# 997                       Shane
# 998       From Here to Eternity
# 999                    Lifeboat
# Name: movie-name, Length: 1000, dtype: object

# %% [markdown]
# # ANALYSIS BASED ON GENRES

# %%
df_imdb.head()

# %%
df_genre_count = df_imdb.genre.value_counts().reset_index().rename(columns={"index":"genre" , "genre":"count"})
df_genre_count
# Out:
#                        genre  count
# 0                      Drama     89
# 1              Comedy, Drama     36
# 2             Drama, Romance     35
# 3     Comedy, Drama, Romance     31
# 4     Crime, Drama, Thriller     30
# ..                       ...    ...
# 199           Family, Sci-Fi      1
# 200   Comedy, Music, Romance      1
# 201  Drama, History, Mystery      1
# 202  Action, Comedy, Mystery      1
# 203          Fantasy, Horror      1
#
# [204 rows x 2 columns]

# %%
sns.barplot( x="count" , y='genre' , data=df_genre_count.head(20))
plt.xlabel("number of movies")
plt.title("GENRE vs NUMBER OF MOVIES")
# Out:
# Text(0.5, 1.0, 'GENRE vs NUMBER OF MOVIES')

# %% [markdown]
# ## analysis for movies with genre DRAMA only

# %%
df_no_of_movies_drama = df_imdb['genre'].str.contains("Drama").fillna(False)
print('Number of movies with Drama','=',len(df_imdb[df]))
# Out:
# Number of movies with Drama = 721

# %%
df_movies_with_genre_drama = df_imdb[df].year.value_counts().to_frame().rename_axis("yr").reset_index().rename(columns={"year":"count"})
df_movies_with_genre_drama.head()
# Out:
#      yr  count
# 0  2013     25
# 1  2006     24
# 2  2004     24
# 3  2007     22
# 4  2016     22

# %%
fig, ax = plt.subplots(figsize=(60,7))
sns.barplot(x="yr" , y="count" , data=df_movies_with_genre_drama ,palette="nipy_spectral" )
# Out:
# <AxesSubplot:xlabel='yr', ylabel='count'>

# %% [markdown]
# ## Ten years with the most number of movies having genre as drama

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.barplot(x="yr" , y="count" , data=df_movies_with_genre_drama.head(10) ,palette="viridis_r" )
plt.title("Genre  --  Drama")
plt.xlabel("years")
plt.ylabel("number of movies")
# Out:
# Text(0, 0.5, 'number of movies')

# %% [markdown]
# # RATING ANALYSIS

# %%
df_imdb.head()
# Out:
#                  movie-name  year  duration(min)                 genre  \
# 0  The Shawshank Redemption  1994            142                 Drama
# 1             The Godfather  1972            175          Crime, Drama
# 2           Soorarai Pottru  2020            153                 Drama
# 3           The Dark Knight  2008            152  Action, Crime, Drama
# 4    The Godfather: Part II  1974            202          Crime, Drama
#
#    rating                                           overview  \
# 0     9.3  Two imprisoned men bond over a number of years...
# 1     9.2  An organized crime dynasty's aging patriarch t...
# 2     9.1  Nedumaaran Rajangam "Maara" sets out to make t...
# 3     9.0  When the menace known as the Joker wreaks havo...
# 4     9.0  The early life and career of Vito Corleone in ...
#
#                director                                          image_url  \
# 0        Frank Darabont  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  Francis Ford Coppola  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2         Sudha Kongara  https://m.media-amazon.com/images/M/MV5BOTc2ZT...
# 3     Christopher Nolan  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 4  Francis Ford Coppola  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#      votes
# 0  2396103
# 1  1659703
# 2    79558
# 3  2357666
# 4  1153712

# %% [markdown]
# ## movies with rating greater than equal 9.0

# %%
movies_greater_than_nine = df_imdb.query('rating >=9')
movies_greater_than_nine
# Out:
#                  movie-name  year  duration(min)                 genre  \
# 0  The Shawshank Redemption  1994            142                 Drama
# 1             The Godfather  1972            175          Crime, Drama
# 2           Soorarai Pottru  2020            153                 Drama
# 3           The Dark Knight  2008            152  Action, Crime, Drama
# 4    The Godfather: Part II  1974            202          Crime, Drama
# 5              12 Angry Men  1957             96          Crime, Drama
#
#    rating                                           overview  \
# 0     9.3  Two imprisoned men bond over a number of years...
# 1     9.2  An organized crime dynasty's aging patriarch t...
# 2     9.1  Nedumaaran Rajangam "Maara" sets out to make t...
# 3     9.0  When the menace known as the Joker wreaks havo...
# 4     9.0  The early life and career of Vito Corleone in ...
# 5     9.0  A jury holdout attempts to prevent a miscarria...
#
#                director                                          image_url  \
# 0        Frank Darabont  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  Francis Ford Coppola  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2         Sudha Kongara  https://m.media-amazon.com/images/M/MV5BOTc2ZT...
# 3     Christopher Nolan  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 4  Francis Ford Coppola  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 5          Sidney Lumet  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#      votes
# 0  2396103
# 1  1659703
# 2    79558
# 3  2357666
# 4  1153712
# 5   706583

# %%
movies_greater_than_nine.plot.bar(x="movie-name" , y="rating" , color="r")
movies_greater_than_nine.plot.bar(x="movie-name" , y="votes")
# Out:
# <AxesSubplot:xlabel='movie-name'>

# %%
sns.barplot( y="movie-name" , x="rating" ,hue="votes", data=df_imdb[df_imdb.rating == df_imdb.rating.max()] , palette="rocket"  )
# Out:
# <AxesSubplot:xlabel='rating', ylabel='movie-name'>

# %% [markdown]
# ## histograph of rating

# %%
sns.distplot(df_imdb['rating'] ,hist=False, color ='green', bins=20, rug=True);
# Out:
# C:\Users\HIMANGSHUB\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HIMANGSHUB\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
df_count_rating = df_imdb.rating.value_counts().to_frame().reset_index().rename(columns={"index":"rating" , "rating":"count"})
df_count_rating.head(10)
# Out:
#    rating  count
# 0     7.7    164
# 1     7.8    145
# 2     8.0    139
# 3     8.1    138
# 4     7.6    113
# 5     7.9    107
# 6     8.2     64
# 7     8.3     46
# 8     8.4     30
# 9     8.5     22

# %%
fig ,ax = plt.subplots(figsize=(15,7))
sns.barplot(x="rating" , y="count", data=df_count_rating)
plt.ylabel("number of movies")
# Out:
# Text(0, 0.5, 'number of movies')

# %%
sns.distplot(x=df_count_rating['rating'] , hist=False, color ='red', bins=20, rug=True)
# Out:
# C:\Users\HIMANGSHUB\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HIMANGSHUB\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # DIRECTOR ANALYSIS

# %%
df_imdb.head()
# Out:
#                  movie-name  year  duration(min)                 genre  \
# 0  The Shawshank Redemption  1994            142                 Drama
# 1             The Godfather  1972            175          Crime, Drama
# 2           Soorarai Pottru  2020            153                 Drama
# 3           The Dark Knight  2008            152  Action, Crime, Drama
# 4    The Godfather: Part II  1974            202          Crime, Drama
#
#    rating                                           overview  \
# 0     9.3  Two imprisoned men bond over a number of years...
# 1     9.2  An organized crime dynasty's aging patriarch t...
# 2     9.1  Nedumaaran Rajangam "Maara" sets out to make t...
# 3     9.0  When the menace known as the Joker wreaks havo...
# 4     9.0  The early life and career of Vito Corleone in ...
#
#                director                                          image_url  \
# 0        Frank Darabont  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  Francis Ford Coppola  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2         Sudha Kongara  https://m.media-amazon.com/images/M/MV5BOTc2ZT...
# 3     Christopher Nolan  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 4  Francis Ford Coppola  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#      votes
# 0  2396103
# 1  1659703
# 2    79558
# 3  2357666
# 4  1153712

# %% [markdown]
# ## top 10 director with the most number of movies

# %%
df_top_director = df_imdb.director.value_counts().reset_index().rename(columns={"index":"director" , "director":"count"})
df_top_director.head()
# Out:
#            director  count
# 0  Alfred Hitchcock     14
# 1  Steven Spielberg     13
# 2    Hayao Miyazaki     11
# 3    Akira Kurosawa     10
# 4   Martin Scorsese     10

# %% [markdown]
# ## Top ten director with the most number of movies

# %%
fig ,ax = plt.subplots(figsize=(17,6))
sns.scatterplot(y="count" , x="director"  , data=df_top_director.head(10) , color="red")
plt.ylabel("number of movies")
plt.title("TOP TEN DIRECTORS WITH THE MOST NUMBER OF MOVIES")
# Out:
# Text(0.5, 1.0, 'TOP TEN DIRECTORS WITH THE MOST NUMBER OF MOVIES')

# %% [markdown]
# ## Moives by Director having the highest number of moives

# %%
df_top_director.head(1)
# Out:
#            director  count
# 0  Alfred Hitchcock     14

# %%
df_AH = df_imdb[df_imdb.director=="Alfred Hitchcock"]
df_copied_df_AH = df_AH.copy()
df_cleaned_AH = df_copied_df_AH.drop(['overview' ,'director' , 'image_url' ] , axis=1)

# %%
print( "\n\n\t\t\t\tMOVIES DIRECTED BY Alfred Hitchcock")
print(tabulate(df_cleaned_AH, headers = 'keys', tablefmt = 'fancy_grid' , showindex="never"))
# Out:
# 				MOVIES DIRECTED BY Alfred Hitchcock
# ╒══════════════════════╤════════╤═════════════════╤══════════════════════════════╤══════════╤═════════╕
# │ movie-name           │   year │   duration(min) │ genre                        │   rating │   votes │
# ╞══════════════════════╪════════╪═════════════════╪══════════════════════════════╪══════════╪═════════╡
# │ Psycho               │   1960 │             109 │ Horror, Mystery, Thriller    │      8.5 │  615847 │
# ├──────────────────────┼────────┼─────────────────┼──────────────────────────────┼──────────┼─────────┤
# │ Rear Window          │   1954 │             112 │ Mystery, Thriller            │      8.5 │  452313 │
# ├──────────────────────┼────────┼─────────────────┼──────────────────────────────┼──────────┼─────────┤
# │ North by Northwest   │   1959 │             136 │ Adventure, Mystery, Thriller │      8.3 │  303958 │
# ├──────────────────────┼────────┼─────────────────┼──────────────────────────────┼──────────┼─────────┤
# │ Vertigo              │   1958 │             128 │ Mystery, Romance, Thriller   │      8.3 │  371468 │
# ├──────────────────────┼────────┼─────────────────┼──────────────────────────────┼──────────┼─────────┤
# │ Dial M for Murder    │   1954 │             105 │ Crime, Thriller              │      8.2 │  161631 │
# ├──────────────────────┼────────┼─────────────────┼──────────────────────────────┼──────────┼─────────┤
# │ Rebecca              │   1940 │             130 │ Drama, Mystery, Romance      │      8.1 │  126439 │
# ├──────────────────────┼────────┼─────────────────┼──────────────────────────────┼──────────┼─────────┤
# │ Strangers on a Train │   1951 │             101 │ Crime, Film-Noir, Thriller   │      8   │  124892 │
# ├──────────────────────┼────────┼─────────────────┼──────────────────────────────┼──────────┼─────────┤
# │ Rope                 │   1948 │              80 │ Crime, Drama, Mystery        │      8   │  132227 │
# ├──────────────────────┼────────┼─────────────────┼──────────────────────────────┼──────────┼─────────┤
# │ Notorious            │   1946 │             102 │ Drama, Film-Noir, Romance    │      8   │   93603 │
# ├──────────────────────┼────────┼─────────────────┼──────────────────────────────┼──────────┼─────────┤
# │ Shadow of a Doubt    │   1943 │             108 │ Film-Noir, Thriller          │      7.8 │   60690 │
# ├──────────────────────┼────────┼─────────────────┼──────────────────────────────┼──────────┼─────────┤
# │ The Lady Vanishes    │   1938 │              96 │ Mystery, Thriller            │      7.8 │   48454 │
# ├──────────────────────┼────────┼─────────────────┼──────────────────────────────┼──────────┼─────────┤
# │ The Birds            │   1963 │             119 │ Drama, Horror, Mystery       │      7.7 │  174537 │
# ├──────────────────────┼────────┼─────────────────┼──────────────────────────────┼──────────┼─────────┤
# │ The 39 Steps         │   1935 │              86 │ Crime, Mystery, Thriller     │      7.7 │   52982 │
# ├──────────────────────┼────────┼─────────────────┼──────────────────────────────┼──────────┼─────────┤
# │ Lifeboat             │   1944 │              97 │ Drama, War                   │      7.6 │   26917 │
# ╘══════════════════════╧════════╧═════════════════╧══════════════════════════════╧══════════╧═════════╛

# %%
sns.jointplot(x="rating" , y="votes" , data=df_cleaned_AH , color="green" , label="RATING and VOTES of Alfred Hitchcock")

# %% [markdown]
# ## Moives by Christopher Nolan

# %%
no_of_movie_by_CN = df_imdb.director.value_counts()["Christopher Nolan"]
print(f"Number of movies Directed by Christopher Nolan :  {no_of_movie_by_CN}"  )
# Out:
# Number of movies Directed by Christopher Nolan :  8

# %%
df_CN = df_imdb[df_imdb.director=="Christopher Nolan"]
df_copied_df_CN = df_CN.copy()

# %%
df_cleaned = df_copied_df_CN.drop(['overview' ,'director' , 'image_url' ] , axis=1)

# %%
from tabulate import tabulate
print( "\n\n\t\t\t\tMOVIES DIRECTED BY CHRISTOPHER NOLAN")
print(tabulate(df_cleaned, headers = 'keys', tablefmt = 'fancy_grid' , showindex="never"))
# Out:
# 				MOVIES DIRECTED BY CHRISTOPHER NOLAN
# ╒═══════════════════════╤════════╤═════════════════╤═══════════════════════════╤══════════╤═════════╕
# │ movie-name            │   year │   duration(min) │ genre                     │   rating │   votes │
# ╞═══════════════════════╪════════╪═════════════════╪═══════════════════════════╪══════════╪═════════╡
# │ The Dark Knight       │   2008 │             152 │ Action, Crime, Drama      │      9   │ 2357666 │
# ├───────────────────────┼────────┼─────────────────┼───────────────────────────┼──────────┼─────────┤
# │ Inception             │   2010 │             148 │ Action, Adventure, Sci-Fi │      8.8 │ 2115635 │
# ├───────────────────────┼────────┼─────────────────┼───────────────────────────┼──────────┼─────────┤
# │ Interstellar          │   2014 │             169 │ Adventure, Drama, Sci-Fi  │      8.6 │ 1560239 │
# ├───────────────────────┼────────┼─────────────────┼───────────────────────────┼──────────┼─────────┤
# │ The Prestige          │   2006 │             130 │ Drama, Mystery, Sci-Fi    │      8.5 │ 1216429 │
# ├───────────────────────┼────────┼─────────────────┼───────────────────────────┼──────────┼─────────┤
# │ The Dark Knight Rises │   2012 │             164 │ Action, Adventure         │      8.4 │ 1546000 │
# ├───────────────────────┼────────┼─────────────────┼───────────────────────────┼──────────┼─────────┤
# │ Memento               │   2000 │             113 │ Mystery, Thriller         │      8.4 │ 1145460 │
# ├───────────────────────┼────────┼─────────────────┼───────────────────────────┼──────────┼─────────┤
# │ Batman Begins         │   2005 │             140 │ Action, Adventure         │      8.2 │ 1333078 │
# ├───────────────────────┼────────┼─────────────────┼───────────────────────────┼──────────┼─────────┤
# │ Dunkirk               │   2017 │             106 │ Action, Drama, History    │      7.8 │  573970 │
# ╘═══════════════════════╧════════╧═════════════════╧═══════════════════════════╧══════════╧═════════╛

# %% [markdown]
# # VOTES ANALYSIS

# %% [markdown]
# ## TOP TEN MOVIES WITH THE HIGHEST NUMBER OF VOTES

# %%
df_votes = df_imdb.sort_values('votes' , ascending=False).copy()
df_copied_for_votes = df_votes.drop(["overview" , "image_url" , 'genre'] , axis=1)
print( "\n\n\t\t\t\t\tTOP TEN MOVIES WITH THE HIGHEST NUMBER OF VOTES")
print(tabulate(df_copied_for_votes[:10], headers = 'keys', tablefmt = 'fancy_grid' , showindex="never"))
# Out:
# 					TOP TEN MOVIES WITH THE HIGHEST NUMBER OF VOTES
# ╒═══════════════════════════════════════════════════╤════════╤═════════════════╤══════════╤══════════════════════╤═════════╕
# │ movie-name                                        │   year │   duration(min) │   rating │ director             │   votes │
# ╞═══════════════════════════════════════════════════╪════════╪═════════════════╪══════════╪══════════════════════╪═════════╡
# │ The Shawshank Redemption                          │   1994 │             142 │      9.3 │ Frank Darabont       │ 2396103 │
# ├───────────────────────────────────────────────────┼────────┼─────────────────┼──────────┼──────────────────────┼─────────┤
# │ The Dark Knight                                   │   2008 │             152 │      9   │ Christopher Nolan    │ 2357666 │
# ├───────────────────────────────────────────────────┼────────┼─────────────────┼──────────┼──────────────────────┼─────────┤
# │ Inception                                         │   2010 │             148 │      8.8 │ Christopher Nolan    │ 2115635 │
# ├───────────────────────────────────────────────────┼────────┼─────────────────┼──────────┼──────────────────────┼─────────┤
# │ Fight Club                                        │   1999 │             139 │      8.8 │ David Fincher        │ 1893461 │
# ├───────────────────────────────────────────────────┼────────┼─────────────────┼──────────┼──────────────────────┼─────────┤
# │ Pulp Fiction                                      │   1994 │             154 │      8.9 │ Quentin Tarantino    │ 1863596 │
# ├───────────────────────────────────────────────────┼────────┼─────────────────┼──────────┼──────────────────────┼─────────┤
# │ Forrest Gump                                      │   1994 │             142 │      8.8 │ Robert Zemeckis      │ 1852744 │
# ├───────────────────────────────────────────────────┼────────┼─────────────────┼──────────┼──────────────────────┼─────────┤
# │ The Matrix                                        │   1999 │             136 │      8.7 │ Lana Wachowski       │ 1711640 │
# ├───────────────────────────────────────────────────┼────────┼─────────────────┼──────────┼──────────────────────┼─────────┤
# │ The Lord of the Rings: The Fellowship of the Ring │   2001 │             178 │      8.8 │ Peter Jackson        │ 1694223 │
# ├───────────────────────────────────────────────────┼────────┼─────────────────┼──────────┼──────────────────────┼─────────┤
# │ The Lord of the Rings: The Return of the King     │   2003 │             201 │      8.9 │ Peter Jackson        │ 1673467 │
# ├───────────────────────────────────────────────────┼────────┼─────────────────┼──────────┼──────────────────────┼─────────┤
# │ The Godfather                                     │   1972 │             175 │      9.2 │ Francis Ford Coppola │ 1659703 │
# ╘═══════════════════════════════════════════════════╧════════╧═════════════════╧══════════╧══════════════════════╧═════════╛

# %%
ax = plt.subplots(figsize=(10,7))
sns.barplot(y="movie-name", x="votes", data=df_copied_for_votes[:11] , palette="CMRmap_r");
plt.title("TOP TEN MOVIES WITH THE HIGHEST NUMBER OF VOTES")
# Out:
# Text(0.5, 1.0, 'TOP TEN MOVIES WITH THE HIGHEST NUMBER OF VOTES')

# %%
df_imdb.head()
# Out:
#                  movie-name  year  duration(min)                 genre  \
# 0  The Shawshank Redemption  1994            142                 Drama
# 1             The Godfather  1972            175          Crime, Drama
# 2           Soorarai Pottru  2020            153                 Drama
# 3           The Dark Knight  2008            152  Action, Crime, Drama
# 4    The Godfather: Part II  1974            202          Crime, Drama
#
#    rating                                           overview  \
# 0     9.3  Two imprisoned men bond over a number of years...
# 1     9.2  An organized crime dynasty's aging patriarch t...
# 2     9.1  Nedumaaran Rajangam "Maara" sets out to make t...
# 3     9.0  When the menace known as the Joker wreaks havo...
# 4     9.0  The early life and career of Vito Corleone in ...
#
#                director                                          image_url  \
# 0        Frank Darabont  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  Francis Ford Coppola  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2         Sudha Kongara  https://m.media-amazon.com/images/M/MV5BOTc2ZT...
# 3     Christopher Nolan  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 4  Francis Ford Coppola  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#      votes
# 0  2396103
# 1  1659703
# 2    79558
# 3  2357666
# 4  1153712

# %% [markdown]
# ## top ten movies with highest rating and votes

# %%
sns.jointplot(x="rating", y="votes", data=df_imdb.head(10) , color="orange" , label="MOVIES WITH HIGH RATING , VOTES");
